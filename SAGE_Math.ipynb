# %%
#Problem 37

# %%
x=var('x')

# %%
def f(x): return 1/sqrt(x^2 - 36)

# %%
p = []

# %%
p.append(plot(f(x),(x, -10, -6.1), color='blue', legend_label='f(x)'))

# %%
p.append(plot(f(x),(x, 6.1, 10), color='blue'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
int = integral(f(x), x)

# %%
int
# Out:
# log(2*x + 2*sqrt(x^2 - 36))

# %%
#Problem 46

# %%
x=var('x')

# %%
def f(x): return x/sqrt(4+5*x)

# %%
plot(f(x),(x, -0.5, 3), color='blue', legend_label='f(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
int = integral(f(x), x)

# %%
int
# Out:
# 2/75*(5*x + 4)^(3/2) - 8/25*sqrt(5*x + 4)

# %%
#Problem 58

# %%
x=var('x')

# %%
def f(x): return 2*x^2 - 2*x

# %%
def g(x): return 12*x^2 - 12*x^3

# %%
p = []

# %%
p.append(plot(f(x),(x,-0.5,1), color='blue', legend_label='f(x)'))

# %%
p.append(plot(g(x),(x,-0.5,1), color='red', legend_label='g(x)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
def s(x): return f(x) - g(x)

# %%
s(x).roots()
# Out:
# [(1, 1), (-1/6, 1), (0, 1)]

# %%
int1 = integral(f(x)- g(x), x, -1/6, 0)

# %%
int1
# Out:
# 13/1296

# %%
int2 = integral(g(x) - f(x), x, 0, 1)

# %%
int2
# Out:
# 4/3

# %%
int1 + int2
# Out:
# 1741/1296

# %%
numerical_approx(1741/1296)
# Out:
# 1.34336419753086
